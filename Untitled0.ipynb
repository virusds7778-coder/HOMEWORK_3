# %% [markdown]
# <a href="https://colab.research.google.com/github/virusds7778-coder/HOMEWORK_3/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print (1 + 1)
# Out:
# 2

# %%
# переменные
"""многострочные коментарии"""
a = 10 + 20
b = a * 30
c = a / b
print ('Ответ: ', c)
# Out:
# Ответ:  0.03333333333333333

# %%
result = 3 + 33 + 333
print("Результат 3 + 33 + 333:", result)
# Out:
# Результат 3 + 33 + 333: 369

# %%
result =  9 + 99 + 999
print("Результат 9 + 99 + 999:", result)
# Out:
# Результат 9 + 99 + 999: 1107

# %%
# Создаем несколько переменных различных типов
целое_число = 10
дробное_число = 20.5
приветствие = "Привет, мир!"
аргумент = True

# Выводим значения переменных на экран
print(10, дробное_число)
# Out:
# 10 20.5

# %% [markdown]
# ### Расчет времени из секунд
#
# Этот блок кода запрашивает у пользователя количество секунд, затем преобразует это значение в часы, минуты и оставшиеся секунды. Включает проверку ввода, чтобы убедиться, что введены только числа.

# %%
# Запрашиваем у пользователя время в секундах
время_в_секундах = input("Введите время в секундах: ")

# Проверяем, состоит ли строка только из числовых данных
if tr.isdigit():
    # Приводим тип строки к целому числу
    total_seconds = int(total_seconds_str)

    # Рассчитываем часы
    hours = total_seconds // 3600  # 3600 секунд в часе
    remaining_seconds_after_hours = total_seconds % 3600

    # Рассчитываем минуты
    minutes = remaining_seconds_after_hours // 60  # 60 секунд в минуте

    # Оставшиеся секунды
    seconds = remaining_seconds_after_hours % 60

    # Выводим результат
    print(f"Общее время: {total_seconds} секунд")
    print(f"Это: {hours} часов, {minutes} минут, {seconds} секунд.")
else:
    print("Ошибка: Введенные данные должны содержать только числовые значения.")
# Out:
# Введите время в секундах: 23568
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1743/657640308.py in <cell line: 0>()
#       3
#       4 # Проверяем, состоит ли строка только из числовых данных
# ----> 5 if tr.isdigit():
#       6     # Приводим тип строки к целому числу
#       7     total_seconds = int(total_seconds_str)
#
# NameError: name 'tr' is not defined

# %%
# Запрашиваем у пользователя время в секундах
время_в_секундах = input("Введите время в секундах: ")

# Проверяем, состоит ли строка только из числовых данных
if время_в_секундах.isdigit():
    # Приводим тип строки к целому числу
    total_seconds = int(время_в_секундах)
    # Рассчитываем часы
    hours = total_seconds // 3600  # 3600 секунд в часе
    remaining_seconds_after_hours = total_seconds % 3600
    # Рассчитываем минуты
    minutes = remaining_seconds_after_hours // 60  # 60 секунд в минуте
    # Оставшиеся секунды
    seconds = remaining_seconds_after_hours % 60
    # Выводим результат
    print(f"Общее время: {total_seconds} секунд")
    print(f"Это: {hours} часов, {minutes} минут, {seconds} секунд.")
else:
    print("Ошибка: Введенные данные должны содержать только числовые значения.")
# Out:
# Введите время в секундах: 12356
# Общее время: 12356 секунд
# Это: 3 часов, 25 минут, 56 секунд.
